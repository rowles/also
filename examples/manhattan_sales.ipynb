# %%
# https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_manhattan.xls

# %%
import pandas as pd

# %%
xls_path = 'https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_manhattan.xls'
df = pd.read_excel(xls_path)

# %%
df.columns =[
        'borough', 'neighborhood', 'building_class_cat',
        'tax_class_pres', 'block', 'lot', 'easement', 'building_class_pres',
        'address', 'apt_num', 'zipcode', 'residential_units', 'commercial_units',
        'total_units', 'land_sq_ft', 'gross_sq_ft', 'year_built',
        'tax_class_sale', 'building_class_sale', 'sale_price', 'sale_date'
    ]
df = df[4:]
orig_df = df.copy()

# %%
len(df)
# Out:
# 16871

# %%
# Out:
#       borough              neighborhood        building_class_cat  \
# 16874       1  WASHINGTON HEIGHTS UPPER  46 CONDO STORE BUILDINGS
# 16875       1  WASHINGTON HEIGHTS UPPER  46 CONDO STORE BUILDINGS
# 16876       1  WASHINGTON HEIGHTS UPPER  46 CONDO STORE BUILDINGS
# 16877       1  WASHINGTON HEIGHTS UPPER  46 CONDO STORE BUILDINGS
# 16878       1  WASHINGTON HEIGHTS UPPER  46 CONDO STORE BUILDINGS
#
#       tax_class_pres block   lot easement building_class_pres        address  \
# 16874              4  2164  1010      NaN                  RK  4260 BROADWAY
# 16875              4  2164  1011      NaN                  RK  4260 BROADWAY
# 16876              4  2164  1012      NaN                  RK  4260 BROADWAY
# 16877              4  2164  1013      NaN                  RK  4260 BROADWAY
# 16878              4  2164  1014      NaN                  RK  4260 BROADWAY
#
#       apt_num  ... residential_units commercial_units total_units land_sq_ft  \
# ...
